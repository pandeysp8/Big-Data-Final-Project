# %%
import os
os.environ["HDF5_USE_FILE_LOCKING"]='FALSE'
import sys
sys.path.append('../src/')
import h5py
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import matplotlib.patches as patches
import pandas as pd
from display.display import get_cmap
from keras.models import Sequential
from keras.models import load_model
from flask import request
from flask import jsonify
from flask import Flask
# Out:
# Using TensorFlow backend.

# %%
app = Flask(__name__)

# %%
mse_file  = "../models/nowcast/mse_model.h5"

def get_model:
    global model
    model= load_model(mse_file)
    print("**Model Loaded**")

def

# %%
test_data_file = "../data/sample/synrad_testing.h5"

# %%
# Load pretrained nowcasting models
mse_file  = "../models/nowcast/mse_model.h5"
mse_model = tf.keras.models.load_model(mse_file,compile=False,custom_objects={"tf": tf})

#style_file = '../models/nowcast/style_model.h5'
#style_model = tf.keras.models.load_model(style_file,compile=False,custom_objects={"tf": tf})

#mse_style_file = '../models/nowcast/mse_and_style.h5'
#mse_style_model = tf.keras.models.load_model(mse_style_file,compile=False,custom_objects={"tf": tf})

#gan_file = '../models/nowcast/gan_generator.h5'
#gan_model = tf.keras.models.load_model(gan_file,compile=False,custom_objects={"tf": tf})

# %%
# Load a part of the test dataset
from readers.nowcast_reader import read_data
x_test,y_test = read_data(test_data_file,end=500)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-fc9dcd67c5c0> in <module>
#       1 # Load a part of the test dataset
# ----> 2 from readers.nowcast_reader import read_data
#       3 x_test,y_test = read_data(test_data_file,end=500)
#
# ModuleNotFoundError: No module named 'readers'

# %%
import boto3
import s3fs
import h5py

s3= s3fs.S3FileSystem()
with s3.open("C:/Users/Swati/Downloads/neurips-2020-sevir-master/data/nowcast_testing.h5", 'rb') as s3File:
    with h5py.File(s3File, 'r') as hf:
        IN= hf ['IN'][s]
        OUT= hf ['OUT'][s]
IN = (IN.astype(dtype)-33.44 )/47.54
OUT= (OUT.astype(dtype)-33.44 )/47.54
# Out:
# ---------------------------------------------------------------------------
# ParamValidationError                      Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\s3fs\core.py in info(self, path, version_id, refresh, **kwargs)
#     487             out = self._call_s3(self.s3.head_object, kwargs, Bucket=bucket,
# --> 488                                 Key=key, **self.req_kw)
#     489             out = {
#
# ~\Anaconda3\lib\site-packages\s3fs\core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     198                                                        **kwargs)
# --> 199         return method(**additional_kwargs)
#     200
#
# ~\Anaconda3\lib\site-packages\botocore\client.py in _api_call(self, *args, **kwargs)
#     385             # The "self" in this scope is referring to the BaseClient.
# --> 386             return self._make_api_call(operation_name, kwargs)
#     387
#
# ~\Anaconda3\lib\site-packages\botocore\client.py in _make_api_call(self, operation_name, api_params)
#     677         request_dict = self._convert_to_request_dict(
# --> 678             api_params, operation_model, context=request_context)
#     679
#
# ~\Anaconda3\lib\site-packages\botocore\client.py in _convert_to_request_dict(self, api_params, operation_model, context)
#     723         api_params = self._emit_api_params(
# --> 724             api_params, operation_model, context)
#     725         request_dict = self._serializer.serialize_to_request(
#
# ~\Anaconda3\lib\site-packages\botocore\client.py in _emit_api_params(self, api_params, operation_model, context)
#     755                 operation_name=operation_name),
# --> 756             params=api_params, model=operation_model, context=context)
#     757         return api_params
#
# ~\Anaconda3\lib\site-packages\botocore\hooks.py in emit(self, event_name, **kwargs)
#     356         aliased_event_name = self._alias_event_name(event_name)
# --> 357         return self._emitter.emit(aliased_event_name, **kwargs)
#     358
#
# ~\Anaconda3\lib\site-packages\botocore\hooks.py in emit(self, event_name, **kwargs)
#     227         """
# --> 228         return self._emit(event_name, kwargs)
#     229
#
# ~\Anaconda3\lib\site-packages\botocore\hooks.py in _emit(self, event_name, kwargs, stop_on_response)
#     210             logger.debug('Event %s: calling handler %s', event_name, handler)
# --> 211             response = handler(**kwargs)
#     212             responses.append((handler, response))
#
# ~\Anaconda3\lib\site-packages\botocore\handlers.py in validate_bucket_name(params, **kwargs)
#     235                 bucket, VALID_BUCKET.pattern, VALID_S3_ARN.pattern))
# --> 236         raise ParamValidationError(report=error_msg)
#     237
#
# ParamValidationError: Parameter validation failed:
# Invalid bucket name "C:": Bucket name must match the regex "^[a-zA-Z0-9.\-_]{1,255}$" or be an ARN matching the regex "^arn:(aws).*:(s3|s3-object-lambda):[a-z\-0-9]+:[0-9]{12}:accesspoint[/:][a-zA-Z0-9\-]{1,63}$|^arn:(aws).*:s3-outposts:[a-z\-0-9]+:[0-9]{12}:outpost[/:][a-zA-Z0-9\-]{1,63}[/:]accesspoint[/:][a-zA-Z0-9\-]{1,63}$"
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-bb69bca8e629> in <module>
#       4
#       5 s3= s3fs.S3FileSystem()
# ----> 6 with s3.open("C:/Users/Swati/Downloads/neurips-2020-sevir-master/data/nowcast_testing.h5", 'rb') as s3File:
#       7     with h5py.File(s3File, 'r') as hf:
#       8         IN= hf ['IN'][s]
#
# ~\Anaconda3\lib\site-packages\s3fs\core.py in open(self, path, mode, block_size, acl, version_id, fill_cache, encoding, **kwargs)
#     352         fdesc = S3File(self, path, mode2, block_size=block_size, acl=acl,
#     353                        version_id=version_id, fill_cache=fill_cache,
# --> 354                        s3_additional_kwargs=kw)
#     355         if 'b' in mode:
#     356             return fdesc
#
# ~\Anaconda3\lib\site-packages\s3fs\core.py in __init__(self, s3, path, mode, block_size, acl, version_id, fill_cache, s3_additional_kwargs)
#    1163         else:
#    1164             try:
# -> 1165                 info = self.info()
#    1166                 self.size = info['Size']
#    1167                 if self.s3.version_aware:
#
# ~\Anaconda3\lib\site-packages\s3fs\core.py in info(self, **kwargs)
#    1181         refresh = self.s3.version_aware
#    1182         return self.s3.info(self.path, version_id=self.version_id,
# -> 1183                             refresh=refresh, **kwargs)
#    1184
#    1185     def metadata(self, refresh=False, **kwargs):
#
# ~\Anaconda3\lib\site-packages\s3fs\core.py in info(self, path, version_id, refresh, **kwargs)
#     498         except (ClientError, ParamValidationError) as e:
#     499             logger.debug("Failed to head path %s", path, exc_info=True)
# --> 500             raise_from(FileNotFoundError(path), e)
#     501
#     502     def object_version_info(self, path, **kwargs):
#
# ~\Anaconda3\lib\site-packages\six.py in raise_from(value, from_value)
#
# FileNotFoundError: C:/Users/Swati/Downloads/neurips-2020-sevir-master/data/nowcast_testing.h5
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.

# %%
m_model= tf.keras.models.load_model("../models/nowcast/mse_model.h5",compile = False)

# %%
mse_model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 384, 384, 13 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 384, 384, 32) 3776        input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 384, 384, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 384, 384, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 384, 384, 32) 9248        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 384, 384, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 384, 384, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 192, 192, 32) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 192, 192, 64) 18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 192, 192, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 192, 192, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 192, 192, 64) 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 192, 192, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 192, 192, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 96, 96, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 96, 96, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 96, 96, 128)  512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 96, 96, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 96, 96, 128)  147584      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 96, 96, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 96, 96, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 48, 48, 128)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 48, 48, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 48, 48, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 48, 48, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 48, 48, 256)  590080      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 48, 48, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 48, 48, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 24, 24, 256)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 24, 24, 1024) 2360320     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 24, 24, 1024) 4096        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 24, 24, 1024) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 24, 24, 1024) 9438208     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 24, 24, 1024) 4096        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 24, 24, 1024) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 48, 48, 256)  1048832     activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 48, 48, 512)  0           activation_7[0][0]
#                                                                  conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 48, 48, 512)  2048        concatenate[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 48, 48, 512)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 48, 48, 256)  1179904     activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 48, 48, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 48, 48, 256)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 48, 48, 256)  590080      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 48, 48, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 48, 48, 256)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 96, 96, 128)  131200      activation_12[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 96, 96, 256)  0           activation_5[0][0]
#                                                                  conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 96, 96, 256)  1024        concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 96, 96, 256)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 96, 96, 128)  295040      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 96, 96, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 96, 96, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 96, 96, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 96, 96, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 96, 96, 128)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 192, 192, 64) 32832       activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 192, 192, 128 0           activation_3[0][0]
#                                                                  conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 192, 192, 128 512         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 192, 192, 128 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 192, 192, 64) 73792       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 192, 192, 64) 256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 192, 192, 64) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 192, 192, 64) 36928       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 192, 192, 64) 256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 192, 192, 64) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 384, 384, 32) 8224        activation_18[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 384, 384, 64) 0           activation_1[0][0]
#                                                                  conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 384, 384, 64) 256         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 384, 384, 64) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 384, 384, 32) 18464       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 384, 384, 32) 128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 384, 384, 32) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 384, 384, 32) 9248        activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 384, 384, 32) 128         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 384, 384, 32) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# output_layer (Conv2D)           (None, 384, 384, 12) 396         activation_21[0][0]
# ==================================================================================================
# Total params: 16,565,900
# Trainable params: 16,556,044
# Non-trainable params: 9,856
# __________________________________________________________________________________________________

# %%
#loss, accr= mse_model.evaluate()
x_test
y_test
# Out:
# array([[[[ 0.24316368,  0.11695417,  0.01177958, ...,  0.01177958,
#            0.18005893,  0.43247792],
#          [ 0.159024  ,  0.11695417, -0.03029025, ...,  0.0328145 ,
#            0.22212876,  0.43247792],
#          [ 0.01177958,  0.09591925, -0.03029025, ...,  0.0328145 ,
#            0.36937317,  0.43247792],
#          ...,
#          [-0.6613378 , -0.6613378 , -0.6613378 , ..., -0.38788384,
#           -0.61926794, -0.6613378 ],
#          [-0.6613378 , -0.6613378 , -0.6613378 , ..., -0.40891877,
#           -0.5771981 , -0.6613378 ],
#          [-0.6613378 , -0.6613378 , -0.6613378 , ..., -0.4299537 ,
#           -0.5771981 , -0.64030284]],
#
#         [[ 0.24316368,  0.11695417,  0.01177958, ..., -0.1985696 ,
#            0.11695417,  0.43247792],
#          [ 0.159024  ,  0.20109384, -0.03029025, ..., -0.05132517,
#            0.18005893,  0.43247792],
#          [ 0.05384942,  0.20109384, -0.03029025, ..., -0.05132517,
#            0.30626842,  0.43247792],
#          ...,
#          [-0.6613378 , -0.6613378 , -0.6613378 , ..., -0.38788384,
#           -0.51409334, -0.6613378 ],
#          [-0.6613378 , -0.6613378 , -0.6613378 , ..., -0.38788384,
#           -0.51409334, -0.64030284],
#          [-0.6613378 , -0.6613378 , -0.6613378 , ..., -0.40891877,
#           -0.51409334, -0.64030284]],
#
#         [[ 0.24316368,  0.20109384,  0.01177958, ..., -0.2196045 ,
#            0.05384942,  0.41144302],
#          [ 0.159024  ,  0.20109384, -0.03029025, ..., -0.1985696 ,
#            0.18005893,  0.43247792],
#          [ 0.11695417,  0.11695417, -0.03029025, ..., -0.1985696 ,
#            0.2852335 ,  0.43247792],
#          ...,
#          [-0.6613378 , -0.6613378 , -0.6613378 , ..., -0.38788384,
#           -0.51409334, -0.6613378 ],
#          [-0.6613378 , -0.6613378 , -0.6613378 , ..., -0.38788384,
#           -0.49305844, -0.64030284],
#          [-0.6613378 , -0.6613378 , -0.6613378 , ..., -0.40891877,
#           -0.49305844, -0.61926794]],
#
#         ...,
#
#         [[-0.64030284, -0.64030284, -0.64030284, ..., -0.64030284,
#           -0.64030284, -0.64030284],
#          [-0.64030284, -0.64030284, -0.64030284, ..., -0.64030284,
#           -0.64030284, -0.64030284],
#          [-0.64030284, -0.64030284, -0.64030284, ..., -0.64030284,
#           -0.64030284, -0.64030284],
#          ...,
#          [-0.5771981 , -0.5561632 , -0.5561632 , ..., -0.64030284,
#           -0.64030284, -0.64030284],
#          [-0.5771981 , -0.5561632 , -0.5771981 , ..., -0.64030284,
#           -0.64030284, -0.64030284],
#          [-0.5771981 , -0.5771981 , -0.5771981 , ..., -0.64030284,
#           -0.64030284, -0.64030284]],
#
#         [[-0.64030284, -0.64030284, -0.64030284, ..., -0.64030284,
#           -0.64030284, -0.64030284],
#          [-0.64030284, -0.64030284, -0.64030284, ..., -0.64030284,
#           -0.64030284, -0.64030284],
#          [-0.64030284, -0.64030284, -0.64030284, ..., -0.64030284,
#           -0.64030284, -0.64030284],
#          ...,
#          [-0.5561632 , -0.5561632 , -0.5771981 , ..., -0.64030284,
#           -0.64030284, -0.61926794],
#          [-0.5771981 , -0.5561632 , -0.5771981 , ..., -0.64030284,
#           -0.64030284, -0.64030284],
#          [-0.5771981 , -0.5771981 , -0.5771981 , ..., -0.64030284,
#           -0.64030284, -0.64030284]],
#
#         [[-0.64030284, -0.64030284, -0.64030284, ..., -0.64030284,
#           -0.64030284, -0.64030284],
#          [-0.64030284, -0.64030284, -0.64030284, ..., -0.64030284,
#           -0.64030284, -0.64030284],
#          [-0.64030284, -0.64030284, -0.64030284, ..., -0.64030284,
#           -0.64030284, -0.64030284],
#          ...,
#          [-0.5561632 , -0.5561632 , -0.5771981 , ..., -0.61926794,
#           -0.64030284, -0.61926794],
#          [-0.5561632 , -0.5561632 , -0.5771981 , ..., -0.64030284,
#           -0.64030284, -0.64030284],
#          [-0.5771981 , -0.5561632 , -0.5771981 , ..., -0.64030284,
#           -0.64030284, -0.64030284]]],
#
#
#        [[[-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          ...,
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ]],
#
#         [[-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          ...,
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ]],
#
#         [[-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          ...,
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ]],
#
#         ...,
#
#         [[-0.6613378 , -0.7034076 , -0.6613378 , ..., -0.6613378 ,
#           -0.6613378 , -0.6613378 ],
#          [-0.6613378 , -0.7034076 , -0.6613378 , ..., -0.6613378 ,
#           -0.6613378 , -0.6613378 ],
#          [-0.7034076 , -0.6613378 , -0.6613378 , ..., -0.7034076 ,
#           -0.6613378 , -0.6613378 ],
#          ...,
#          [-0.6613378 , -0.6613378 , -0.6613378 , ..., -0.6613378 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.6613378 , -0.6613378 , -0.6613378 , ..., -0.6613378 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.6613378 , -0.6613378 , -0.6613378 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ]],
#
#         [[-0.6613378 , -0.7034076 , -0.6613378 , ..., -0.6613378 ,
#           -0.6613378 , -0.6613378 ],
#          [-0.6613378 , -0.7034076 , -0.6613378 , ..., -0.6613378 ,
#           -0.6613378 , -0.6613378 ],
#          [-0.7034076 , -0.6613378 , -0.6613378 , ..., -0.6613378 ,
#           -0.6613378 , -0.6613378 ],
#          ...,
#          [-0.6613378 , -0.7034076 , -0.6613378 , ..., -0.6613378 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.6613378 , -0.6613378 , -0.6613378 , ..., -0.6613378 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.6613378 , -0.6613378 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ]],
#
#         [[-0.6613378 , -0.7034076 , -0.6613378 , ..., -0.6613378 ,
#           -0.6613378 , -0.6613378 ],
#          [-0.6613378 , -0.7034076 , -0.6613378 , ..., -0.6613378 ,
#           -0.6613378 , -0.6613378 ],
#          [-0.7034076 , -0.6613378 , -0.6613378 , ..., -0.6613378 ,
#           -0.6613378 , -0.6613378 ],
#          ...,
#          [-0.6613378 , -0.7034076 , -0.6613378 , ..., -0.6613378 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.6613378 , -0.7034076 , -0.6613378 , ..., -0.6613378 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.6613378 , -0.6613378 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ]]],
#
#
#        [[[-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.5561632 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.5561632 ],
#          ...,
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ]],
#
#         [[-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.5771981 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.5561632 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.5561632 ],
#          ...,
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ]],
#
#         [[-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.61926794],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.5561632 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.5561632 ],
#          ...,
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ]],
#
#         ...,
#
#         [[-0.7034076 , -0.7034076 , -0.64030284, ..., -0.7034076 ,
#           -0.7034076 , -0.64030284],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          ...,
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.5771981 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.5771981 ]],
#
#         [[-0.7034076 , -0.7034076 , -0.64030284, ..., -0.7034076 ,
#           -0.7034076 , -0.64030284],
#          [-0.7034076 , -0.7034076 , -0.64030284, ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          ...,
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.5771981 ]],
#
#         [[-0.7034076 , -0.7034076 , -0.64030284, ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.64030284, ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          ...,
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ]]],
#
#
#        ...,
#
#
#        [[[-0.6613378 , -0.6613378 , -0.6613378 , ...,  0.13798909,
#           -0.00925533, -0.36684895],
#          [-0.6613378 , -0.6613378 , -0.6613378 , ...,  0.159024  ,
#            0.159024  , -0.1985696 ],
#          [-0.6613378 , -0.6613378 , -0.6613378 , ...,  0.2641986 ,
#            0.20109384, -0.3247791 ],
#          ...,
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ]],
#
#         [[-0.6613378 , -0.6613378 , -0.6613378 , ...,  0.11695417,
#            0.07488433, -0.1985696 ],
#          [-0.6613378 , -0.6613378 , -0.6613378 , ...,  0.11695417,
#            0.22212876, -0.1985696 ],
#          [-0.6613378 , -0.6613378 , -0.6613378 , ...,  0.159024  ,
#            0.30626842, -0.3247791 ],
#          ...,
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ]],
#
#         [[-0.6613378 , -0.6613378 , -0.6613378 , ...,  0.11695417,
#            0.13798909, -0.3247791 ],
#          [-0.6613378 , -0.6613378 , -0.6613378 , ...,  0.07488433,
#            0.20109384, -0.3247791 ],
#          [-0.6613378 , -0.6613378 , -0.6613378 , ...,  0.07488433,
#            0.30626842, -0.34581402],
#          ...,
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ]],
#
#         ...,
#
#         [[-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          ...,
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ]],
#
#         [[-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          ...,
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ]],
#
#         [[-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          ...,
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ]]],
#
#
#        [[[-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          ...,
#          [-0.64030284, -0.7034076 , -0.7034076 , ..., -0.5771981 ,
#           -0.59823304, -0.61926794],
#          [-0.61926794, -0.7034076 , -0.7034076 , ..., -0.5561632 ,
#           -0.59823304, -0.64030284],
#          [-0.59823304, -0.7034076 , -0.7034076 , ..., -0.13546485,
#           -0.59823304, -0.64030284]],
#
#         [[-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          ...,
#          [-0.64030284, -0.7034076 , -0.7034076 , ..., -0.5771981 ,
#           -0.64030284, -0.61926794],
#          [-0.59823304, -0.7034076 , -0.7034076 , ..., -0.5561632 ,
#           -0.5771981 , -0.61926794],
#          [-0.51409334, -0.7034076 , -0.7034076 , ..., -0.5351283 ,
#           -0.5771981 , -0.64030284]],
#
#         [[-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          ...,
#          [-0.61926794, -0.7034076 , -0.7034076 , ..., -0.59823304,
#           -0.64030284, -0.61926794],
#          [-0.59823304, -0.7034076 , -0.7034076 , ..., -0.5771981 ,
#           -0.5771981 , -0.61926794],
#          [-0.51409334, -0.7034076 , -0.7034076 , ..., -0.5561632 ,
#           -0.49305844, -0.59823304]],
#
#         ...,
#
#         [[-0.6613378 , -0.6613378 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.64030284, -0.6613378 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.64030284, -0.64030284, -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          ...,
#          [ 0.70593184,  0.57972234,  0.83214134, ...,  0.5376525 ,
#            0.57972234,  0.93731594],
#          [ 0.81110644,  0.6217922 ,  0.83214134, ...,  0.6428271 ,
#            0.57972234,  0.8742112 ],
#          [ 0.6428271 ,  0.7269668 ,  0.7269668 , ...,  0.70593184,
#            0.7269668 ,  0.81110644]],
#
#         [[-0.6613378 , -0.6613378 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.6613378 , -0.6613378 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.64030284, -0.64030284, -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          ...,
#          [ 0.55868745,  0.5376525 ,  0.7269668 , ...,  0.55868745,
#            0.5376525 ,  0.68489695],
#          [ 0.70593184,  0.55868745,  0.66386205, ...,  0.70593184,
#            0.7269668 ,  0.7690366 ],
#          [ 0.6428271 ,  0.7269668 ,  0.6217922 , ...,  0.7690366 ,
#            0.7269668 ,  0.7690366 ]],
#
#         [[-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.6613378 , -0.6613378 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.6613378 , -0.6613378 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          ...,
#          [ 0.45351285,  0.43247792,  0.66386205, ...,  0.66386205,
#            0.5376525 ,  0.68489695],
#          [ 0.6007573 ,  0.55868745,  0.6217922 , ...,  0.70593184,
#            0.5376525 ,  0.68489695],
#          [ 0.6428271 ,  0.57972234,  0.55868745, ...,  0.7480017 ,
#            0.6007573 ,  0.68489695]]],
#
#
#        [[[-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          ...,
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ]],
#
#         [[-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          ...,
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ]],
#
#         [[-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          ...,
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ]],
#
#         ...,
#
#         [[-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          ...,
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ]],
#
#         [[-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          ...,
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ]],
#
#         [[-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          ...,
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ],
#          [-0.7034076 , -0.7034076 , -0.7034076 , ..., -0.7034076 ,
#           -0.7034076 , -0.7034076 ]]]], dtype=float32)

# %%
mse_model.compile(optimizer='adam',
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy']
              )

# %%
accr = mse_model.evaluate(x_test,y_test, verbose=0)

# %%
print("Model Accuracy on Original Title Text: ",'{:.2%}'.format(accr[1]))
# Out:
# Model Accuracy on Original Title Text:  0.00%

# %%
# -*- coding: utf-8 -*-
import argparse
import logging

import os
import h5py
os.environ["HDF5_USE_FILE_LOCKING"]='FALSE'

import sys
import numpy as np
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-baa9704ca9d3> in <module>
#      10 import numpy as np
#      11 import tensorflow as tf
# ---> 12 from synrad_generator import get_synrad_train_generator,get_synrad_test_generator
#
# ModuleNotFoundError: No module named 'synrad_generator'
